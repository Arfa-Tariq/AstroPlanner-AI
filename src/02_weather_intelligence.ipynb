# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/AstroPlanner-AI/blob/main/src/02_weather_intelligence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
# !pip install requests -q
