# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/AstroPlanner-AI/blob/main/orchestrator_run_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
os.environ["SUPABASE_URL"] = userdata.get("SUPABASE_URL")
os.environ["SUPABASE_KEY"] = userdata.get("SUPABASE_KEY")
os.environ["GROQ_API_KEY"] = userdata.get("groq_key")
os.environ["DATABASE_URL"] = userdata.get("DATABASE_URL")

# %%
# !if [ -d AstroPlanner-AI ]; then git -C AstroPlanner-AI pull; else git clone https://github.com/Arfa-Tariq/AstroPlanner-AI.git; fi
# !pip install supabase langchain-core langchain-groq langgraph astropy astroplan skyfield timezonefinder tzdata requests -q
import sys; sys.path.append('/content/AstroPlanner-AI/src')
# Out:
# Cloning into 'AstroPlanner-AI'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 297 (delta 83), reused 9 (delta 9), pack-reused 170 (from 1)
# Receiving objects: 100% (297/297), 237.21 KiB | 9.49 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.4/370.4 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 MB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.6 MB/s eta 0:00:00
# ...

# %%
# Verifies the pull above actually landed the current code — if either
# grep prints nothing, the repo on disk is stale and must NOT proceed.
# !grep -n "def get_or_create_user" /content/AstroPlanner-AI/src/storage.py
# !grep -n "_configure_connection" /content/AstroPlanner-AI/src/orchestrator.py
# Out:
# 53:def get_or_create_user(name: str) -> str:
# 65:    def _configure_connection(conn):
# 80:        configure=_configure_connection,

# %%
# !pip install "langgraph-checkpoint-postgres" "psycopg[binary,pool]"
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 62.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import sys; sys.path.append("src")
import storage

# uid = storage.get_or_create_user("test_user")
# print("user_id:", uid)

# sid = storage.create_session(uid, 33.2, 32.4, "2026-08-03")
# print("session_id:", sid)

# storage.save_stage_result(sid, "weather", {"fake": "data"})
# print(storage.get_latest_stage_result(sid, "weather"))
# print(storage.list_recent_sessions(uid))

# %%
# %cd /content/AstroPlanner-AI/src
# Out:
# /content/AstroPlanner-AI/src

# %%
# !python orchestrator.py
# Out:
# /content/AstroPlanner-AI/src/orchestrator.py:457: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(
# [#################################] 100% de421.bsp
# Your observing session for tonight at latitude 33.2, longitude 32.4, with an 8-inch (200mm) telescope, 1000mm focal length, and beginner level is planned. The session includes targets such as NGC6210, NGC6572, NGC6720 (Ring Nebula), NGC6826 (Blinking Planetary), NGC6853 (Dumbbell Nebula), NGC6960 (Veil Nebula), and NGC7027. The session also includes daytime viewing of Venus, Saturn, and the Moon. For more information, you can use the session_id to call get_session_context.

# %%
from orchestrator import chat

# %%
print(chat("What have I planned recently?", user_name="andrew", thread_id="recent_sessions_test"))
# Out:
# You have two recent observation sessions:
#
# 1. Session ID: 7feca663-4354-4d1b-81e2-4fceda3bf8e5
#    Date: 2026-08-03
#    Location: Latitude 33.2, Longitude 32.4
#    Revision Number: 1
#
# 2. Session ID: 9e5eeba0-fb2c-4f58-9447-a362cc0ed35e
#    Date: 2026-08-03
#    Location: Latitude 33.2, Longitude 32.4
#    Revision Number: 1
#
# Let me know if you'd like to know more about either of these sessions or if you'd like to plan a new observation session!

# %%
print(chat("Why was NGC6210 recommended in my last session?", user_name="andrew", thread_id="recent_sessions_test"))
# Out:
# NGC6210 was not recommended in your last session. The top recommended objects for the first two nights were Mercury, Jupiter, Mars, Venus, and Saturn. If you'd like to know more about these objects or why they were recommended, I can try to help!

# %%
print(chat("Hi, what's my recent session?", user_name="andrew", thread_id="recent_sessions_test"))
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_4073/1969673597.py in <cell line: 0>()
# ----> 1 print(chat("Hi, what's my recent session?", user_name="andrew", thread_id="recent_sessions_test"))
#
# /content/AstroPlanner-AI/src/orchestrator.py in chat(user_message, user_name, thread_id)
#     541
#     542     config = {"configurable": {"thread_id": thread_id}}
# --> 543     result = agent.invoke({"messages": [{"role": "user", "content": user_message}]}, config)
#     544     reply = result["messages"][-1].content
#     545
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3911         else:
#    3912             # v1: collect interrupts from updates stream
# ...

# %%
import knowledge
knowledge.seed_knowledge_base()
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
print(chat("What is the Orion Nebula?", user_name="andrew", thread_id="knowledge_test"))
# Out:
# The Orion Nebula is a famous astronomical object, but it seems there's no information about it in the knowledge base. If you'd like to know more, I can try to find general information about it.
