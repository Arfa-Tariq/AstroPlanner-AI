# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfa-Tariq/AstroPlanner-AI/blob/main/orchestrator_run_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
os.environ["SUPABASE_URL"] = userdata.get("SUPABASE_URL")
os.environ["SUPABASE_KEY"] = userdata.get("SUPABASE_KEY")
os.environ["GROQ_API_KEY"] = userdata.get("groq_key")

# %%
# !git clone https://github.com/Arfa-Tariq/AstroPlanner-AI.git 2>/dev/null || !git -C AstroPlanner-AI pull
# !pip install supabase langchain-core langchain-groq langgraph astropy astroplan skyfield timezonefinder tzdata requests -q
import sys; sys.path.append('/content/AstroPlanner-AI/src')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.4/370.4 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 MB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.1/218.1 kB 14.0 MB/s eta 0:00:00
#   Building wheel for astroplan (pyproject.toml) ... done

# %%
import sys; sys.path.append("src")
import storage

uid = storage.get_or_create_user("test_user")
print("user_id:", uid)

sid = storage.create_session(uid, 33.2, 32.4, "2026-08-03")
print("session_id:", sid)

storage.save_stage_result(sid, "weather", {"fake": "data"})
print(storage.get_latest_stage_result(sid, "weather"))
print(storage.list_recent_sessions(uid))
# Out:
# user_id: 99c3984f-bff0-48ba-8673-63720c70e7b2
# session_id: b131c508-9751-4333-96b5-2c954e369f28
# {'fake': 'data'}
# [{'id': 'b131c508-9751-4333-96b5-2c954e369f28', 'latitude': 33.2, 'longitude': 32.4, 'generated_at': '2026-08-03', 'revision_number': 1, 'notes': None, 'created_at': '2026-08-02T21:14:21.417505+00:00'}]

# %%
# %cd /content/AstroPlanner-AI/src
# Out:
# /content/AstroPlanner-AI/src

# %%
# !python orchestrator.py
# Out:
# /content/AstroPlanner-AI/src/orchestrator.py:222: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(
# [#################################] 100% de421.bsp
# Based on your request, I have generated an observation plan for you. The plan includes a list of recommended targets for each night, along with their start and end times, peak viewing times, and other relevant details.
#
# Please note that this plan is tailored to your location, telescope, and experience level. However, since you don't have a camera on file, the plan doesn't include field-of-view analysis. If you'd like to add camera specs to enable this feature, you can do so by providing the necessary information.
#
# Here's a summary of the plan:
#
# * Date: 2026-08-02
# * Targets:
#   - NGC6210 (20:12 - 20:32)
#   - NGC6572 (21:04 - 21:24)
#   - NGC6720 (21:46 - 22:06)
#   - NGC6826 (22:38 - 22:58)
#   - NGC6853 (22:59 - 23:19)
#   - NGC6960 (23:41 - 00:01)
#   - NGC7027 (00:02 - 00:22)
# * Daytime bonus targets:
#   - Venus (14:40 - 15:00)
#   - Moon (03:00 - 03:20)
#   - Saturn (03:50 - 04:10)
#
# * Date: 2026-08-03
# * Targets:
#   - NGC6210 (20:11 - 20:31)
#   - NGC6572 (21:02 - 21:22)
#   - NGC6720 (21:43 - 22:03)
#   - NGC6826 (22:35 - 22:55)
#   - NGC6853 (22:55 - 23:15)
#   - NGC6960 (23:36 - 23:56)
#   - NGC7027 (23:56 - 00:16)
# * Daytime bonus targets:
#   - Venus (14:40 - 15:00)
#   - Saturn (03:50 - 04:10)
#   - Moon (03:50 - 04:10)
#
# * Date: 2026-08-04
# * Targets:
#   - NGC6210 (20:10 - 20:30)
#   - NGC6572 (21:01 - 21:21)
#   - NGC6720 (21:43 - 22:03)
#   - NGC6853 (22:44 - 23:04)
#   - NGC6960 (23:36 - 23:56)
#   - NGC7027 (23:56 - 00:16)
# * Daytime bonus targets:
#   - Venus (14:40 - 15:00)
#   - Saturn (03:40 - 04:00)
#   - Moon (04:30 - 04:50)
#
# Remember to check the weather forecast before heading out for your observation session. Clear skies!
